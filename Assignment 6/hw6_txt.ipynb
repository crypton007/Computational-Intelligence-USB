# %% [markdown]
# # Nature inspired optimization
#
# ## Task 1 - Genetic Algorithm
#
# Write genetic algorithm in Python and solve the Knapsack problem.

# %% [markdown]
# Weights in Kg and costs in EUR for a set of 64 items are given. The goal of the optimization algorithm is to select items to knapsack so that the cost of items reaches the maximum and weight of items do not exceed the knapsack weight limit.
#
# After writing your algorithm change weights and costs to test the algorithm again.

# %%
# Example
import numpy as np
import random

# 64 items and their weights.
# Replace the weights with your own set of weights
# 
weights_of_items = np.array([
    2.3, 8.1, 6., 4.2, 1.3, 2.9, 7., 7.9,
    3.6, 5., 3.1, 5., 3.4, 5.3, 0.8, 6.9,
    9.8, 4.4, 5.4, 7.5, 4.6, 0.3, 9.2, 8.8,
    2.2, 3.3, 9.9, 7.6, 5.9, 4.2, 4.9, 5.8,
    4.4, 2.9, 0.1, 2.4, 5.6, 7.8, 7., 7.5,
    7.3, 7.4, 6.4, 1.6, 6.8, 4., 4.6, 4.1,
    0.5, 6.3, 5.2, 1.5, 9.7, 1.6, 2.6, 1.3,
    6.5, 2.6, 7.8, 6.3, 8.4, 9.4, 1.4, 7.5])
#
#  64 costs corresponding to weights
#  Replace the weights with your own set of weights
costs_of_items = [ 
           6.,  17.,  10., 26.,  19.,  81.,  67., 36.,
          21.,  33.,  13.,  5., 172., 138., 185., 27.,
           4.,   3.,  11., 19.,  95.,  90.,  24., 20.,
          28.,  19.,   7., 28.,  14.,  43.,  40., 12.,
          25.,  37.,  25., 16.,  85.,  20.,  15., 59.,
          72., 168.,  30., 57.,  49.,  66.,  75., 23.,
          79.,  20., 104.,  9.,  32.,  46.,  47., 55.,
          21.,  18.,  23., 44.,  61.,   8.,  42.,  1.]
#
# Knapsack weight limit 
# 
knapsack_weight_limit = 100
#
print("weight -> cost  | cost per kilo") 
for i in range(len(weights_of_items)):
  print("{:-4.1f}kg -> {:-4.0f}€ | {:.1f}".format(
      weights_of_items[i], costs_of_items[i], 
        costs_of_items[i]/weights_of_items[i]))
# Out:
# weight -> cost  | cost per kilo
#  2.3kg ->    6€ | 2.6
#  8.1kg ->   17€ | 2.1
#  6.0kg ->   10€ | 1.7
#  4.2kg ->   26€ | 6.2
#  1.3kg ->   19€ | 14.6
#  2.9kg ->   81€ | 27.9
#  7.0kg ->   67€ | 9.6
#  7.9kg ->   36€ | 4.6
#  3.6kg ->   21€ | 5.8
#  5.0kg ->   33€ | 6.6
#  3.1kg ->   13€ | 4.2
#  5.0kg ->    5€ | 1.0
#  3.4kg ->  172€ | 50.6
#  5.3kg ->  138€ | 26.0
#  0.8kg ->  185€ | 231.2
#  6.9kg ->   27€ | 3.9
#  9.8kg ->    4€ | 0.4
#  4.4kg ->    3€ | 0.7
#  5.4kg ->   11€ | 2.0
#  7.5kg ->   19€ | 2.5
#  4.6kg ->   95€ | 20.7
#  0.3kg ->   90€ | 300.0
#  9.2kg ->   24€ | 2.6
#  8.8kg ->   20€ | 2.3
#  2.2kg ->   28€ | 12.7
#  3.3kg ->   19€ | 5.8
#  9.9kg ->    7€ | 0.7
#  7.6kg ->   28€ | 3.7
#  5.9kg ->   14€ | 2.4
#  4.2kg ->   43€ | 10.2
#  4.9kg ->   40€ | 8.2
#  5.8kg ->   12€ | 2.1
#  4.4kg ->   25€ | 5.7
#  2.9kg ->   37€ | 12.8
#  0.1kg ->   25€ | 250.0
#  2.4kg ->   16€ | 6.7
#  5.6kg ->   85€ | 15.2
#  7.8kg ->   20€ | 2.6
#  7.0kg ->   15€ | 2.1
#  7.5kg ->   59€ | 7.9
#  7.3kg ->   72€ | 9.9
#  7.4kg ->  168€ | 22.7
#  6.4kg ->   30€ | 4.7
#  1.6kg ->   57€ | 35.6
#  6.8kg ->   49€ | 7.2
#  4.0kg ->   66€ | 16.5
#  4.6kg ->   75€ | 16.3
#  4.1kg ->   23€ | 5.6
#  0.5kg ->   79€ | 158.0
#  6.3kg ->   20€ | 3.2
#  5.2kg ->  104€ | 20.0
#  1.5kg ->    9€ | 6.0
#  9.7kg ->   32€ | 3.3
#  1.6kg ->   46€ | 28.8
#  2.6kg ->   47€ | 18.1
#  1.3kg ->   55€ | 42.3
#  6.5kg ->   21€ | 3.2
#  2.6kg ->   18€ | 6.9
#  7.8kg ->   23€ | 2.9
#  6.3kg ->   44€ | 7.0
#  8.4kg ->   61€ | 7.3
#  9.4kg ->    8€ | 0.9
#  1.4kg ->   42€ | 30.0
#  7.5kg ->    1€ | 0.1

# %% [markdown]
# ### Parameters of the algorithm
#
#
#
# *   **chromosome_size** - dimension of the chromosome vector. We have 64 items so that the chromosome_size is equal to 64
# *   **population_size** - number of individuals in the population
# *   **parent_count** - number of parents that are selected from the population on the base of the roulette selection. The parent count must be less than population size.
# *   **probability_of_ones_in_a_new_chromosome** - probability which is used for initial population generation. It is probability of one in the initial chromosome. High values may lead to generation of many individuals with fitness equal to zero. This parameter is specific for our method of generation the initial chromosome. This parameter is meaningless if you choice another method.
# * **probability_of_crossover** - probability of crossover
# * **probability_of_mutation** - probability of mutation. We recommend to start at the value of 1/ga_chromosome_size and increase later

# %%
# Example

# Genetic algorithm parameters
ga_chromosome_size = len(weights_of_items)
ga_probability_of_ones_in_a_new_chromosome = 0.1
ga_probability_of_crossover = 0.3
ga_probability_of_mutation  = 1.0 / ga_chromosome_size
ga_population_size = 100
ga_parent_count = ga_population_size * 3 // 4 # 3/4 of the population size
ga_generations = 100

# %% [markdown]
# ### Algorithm components
#
# #### Fitness function definition
#
# Let ${\bf w}$ is the weight vector, ${\bf c}$ is the cost vector, ${\bf g}$ is a chromosome and L is the weight limit, we define the fitness function as
#
# $$\text{fitness}({\bf g}) =
# \begin{cases}
#   0 & \text{iff} \quad \sum_{i=0}^{N-1}w_ig_i > L \\
#   \sum_{i=0}^{N-1}c_ig_i & \text{otherwise}
# \end{cases}$$
#
# Define the fitness function
# ```python
# def fitness(w, c, L, g):
#   return f #fitness
# ```

# %%
def fitness(w,c,L,g):
  f = []
  wg = []
  cg = []
  for i in range(len(w)):
    wg.append(w[i]*g[i])
    cg.append(c[i]*g[i])
  if np.sum(wg) > L:
    f.append(0)
  else:
    f.append(np.sum(cg))
  return f

# %% [markdown]
# #### Chromosome Initialization
#
# Let $p$ is the initialization probability for 1 in a new chromosome, $\psi$ is a random value with the unique distribution in the range of $<0,1>$ and ${\bf g}$ is a new chromosome then
#
# $$g_i =
# \begin{cases}
#   1 &  \text{iff} \quad \psi < p \\
#   0 &  \text{otherwise}
# \end{cases}$$
#
# for all $i \in <0, N-1>$ where $N=|{\bf g}|$.
#
# The $p$ should be sufficiently low to generate a valid solution with non-zero fitness. Check the validity of the solution after chromosome creation and recreate it if the total weight of the knapsack is above the weight limit $L$. More formally for a valid solution
#
# $$\sum_{i=0}^{N-1}w_ig_i < L$$
#
# where ${\bf w}$ is the weight vector.
#
# This is recommended, but not mandatory way how to initialize a new chromosome. Be aware that producing non-valid solutions with zero fitness at start may disturb the algorithm.
#
# Define python function
# ```python
# def generate_chromosome(N, w, L, p):
#   pass
# ```

# %%
def generate_chromosome(N,w,L,p):
  g = []
  omg = []
  for i in range(N):
    omg.append(random.random())
  wg = []
  for i in range(N):
    if omg[i]<p:
      g.append(1)
    else:
      g.append(0)
  for i in range(N):
     wg.append(w[i]*g[i])
  if np.sum(wg)<L:
    return g

# %% [markdown]
# #### Initialize the population
#
# The population is represented by a numpy matrix. Rows of the matrix correspond to individuals, columns corresponds to genes in the chromosome. Our matrix has 64 columns because we have 64 items.
#
# Call ```generate_chromosome()``` function for each row of the matrix.
#
# Define python function
#
# ```python
# def initialize_population(population_size,
#          chromosome_size, weights, weight_limit,
#          probability_of_ones_in_a_new_chromosome):
#          ...
#          return population
# ```

# %%
def initialize_population(population_size,chromosome_size,weights,
                          weight_limit,probability_of_ones_in_a_new_chromosome):
  population = []   
  for i in range(population_size):
    vec=generate_chromosome(chromosome_size,weights,weight_limit,probability_of_ones_in_a_new_chromosome)
    population.append(vec) 
  return population

# %% [markdown]
# #### Evaluate fitness
#
# Apply fitness function to all rows of the population matrix. The result is a vector of fitness values for all individuals in the population. The vector has the same size as the size of the population.
#
# ```
# def evaluate_fitness(population, weights, costs, weight_limit)
#   pass
# ```

# %%
def evaluate_fitness(population, weights, costs, weight_limit):
  vec = []
  for i in range(len(population)):
    vec.append(fitness(weights,costs,weight_limit,population[i]))
  return vec

# %% [markdown]
# #### Roulette Selection
#
# Implement roulette selection. First create a "roulette", i.e. an array of the same size as the population size $N$ where each element $r_i$ is equal to
#
# $$r_i = \frac{f_j}{F} + r_{i-1}; r_{-1}=0, F = \sum_{k=0}^{N-1}f_k$$
#
# Generate a random number $\psi \in <0,1>$ (uniform distribution) and find the index $i$ in the ${\bf r}$ array so that $r_{i-1} < \psi <= r_i$.
#
# Hint: use ```numpy.searchsorted``` function. What is the complexity of the search with respect to the population size ?

# %%
def roulette(N,p,w,c,L):
  f = evaluate_fitness(p,w,c,L)
  r = []
  ind = 0
  F = np.sum(f)
  r.append((f[0]/F)+0)
  for i in range(1, N-1):
    r.append((f[i]/F)+r[i-1])
  for i in range(1,N-1):
      omg = random.uniform(0,1)
      if omg<=r[i]:
        if r[i-1]<omg:
          ind = i
  return p[ind]

# %% [markdown]
# #### Crossover
#
# Let ${\bf a}$ is a chromosome, ${\bf b}$ is a chromosome, $p$ is a probability of crossover and $N = |{\bf a}| = |{\bf b}|$. Generate randomly an index $i$ in the range of $i \in <0, N - 1>$. Further generate a real random number $\psi \in <0,1>$ from uniform distribution. Create a new chromosome ${\bf r}$ according to
#
# $$
# r_k =
# \begin{cases}
#     b_k & k <= i \land \psi < p\\
#     a_k & \text{otherwise}
# \end{cases}
# $$
#
# for all $k$ in the range of $<0, N-1>$
#
# Define python function
# ```python
# define crossover(a, b, p):
#   ...
#   return r
# ```

# %%
def crossover(a,b,p):
  r = []
  for i in range(len(a)):
    omg = random.uniform(0,1)
    if omg < p:
      r.append(b[i])
    else:
      r.append(a[i])
  return r

# %% [markdown]
# #### Mutation
#
# Let ${\bf g}$ is a chromosome and $N =|{\bf g}|$ is the length of the chromosome. For each index $i \in <0, N-1>$ generate a real random number $\psi$ from uniform distribution and create a new chromosome ${\bf r}$ according to
# $$
# r_i=
# \begin{cases}
# 0 & \quad g_i = 1 \land \psi < p \\
# 1 & \quad g_i = 0 \land \psi < p \\
# g_i & \text{otherwise}
# \end{cases}
# $$
#
# for all indexes $i \in <0, N-1>$.
#
# Define a python function
# ```python
# def mutation(g, p):
#     ...
#     return m
# ```

# %%
def mutation(g, p):
  r = []
  for i in range(len(g)):
    omg = random.uniform(0,1)
    if g[i]==0 and omg < p:
      r.append(1)
    if g[i]==1 and omg < p:
      r.append(0)
    else:
      r.append(g[i])
  return r

# %% [markdown]
# ### Genetic Algorithm
#
# Implement the genetic algorithm according to following pseudocode
#
# ```pseudocode
# init_population
# evaluate_fitness
# for i in range(generations):
#     parents <- roulette_selection (parent_size)
#     copy parents to new population
#     fill new population by chromosomes obtained
#        by crossover followed by mutation to ensure
#        that new population will reach
#        the population_size
#     evaluate_fitness
# ```
#
# In the loop collect history as the best solution (highest fitness), the total weight of that solution and other useful information as generation number, minimum weight, maximum weight and minimum cost.

# %%
best_cost=[] 
min_cost=[]
best_weight=[] 
min_weight=[]
max_weight=[]
for g in range(ga_generations):
  pop = initialize_population(ga_population_size,ga_chromosome_size,weights_of_items,
                          knapsack_weight_limit,ga_probability_of_ones_in_a_new_chromosome)
  fit = evaluate_fitness(pop,weights_of_items,costs_of_items,knapsack_weight_limit)
  children = []
  parents = []
  ind = 0
  for i in range(ga_population_size):
    parents.append(roulette(ga_population_size,pop,weights_of_items,costs_of_items,knapsack_weight_limit))
  for i in range(ga_population_size-1):
    p1,p2 = parents[i], parents[i+1]
    c=crossover(p1,p2,ga_probability_of_crossover)
    m=mutation(c, ga_probability_of_mutation)
    children.append(m)
  fit = evaluate_fitness(children, weights_of_items,costs_of_items,knapsack_weight_limit)
  ind = fit.index(np.max(fit))
  best_cost.append(np.max(fit))
  min_cost.append(np.min(fit))
  best_weight.append(np.mean(children[ind]))
  min_weight.append(np.min(children[ind]))
  max_weight.append(np.max(children[ind]))
  print("Highest Fitness", np.max(fit))
  print("Generation Number", g)
  print("Weight of Solution", np.sum(children[ind]))
  print("Minimum Weight", np.min(children[ind]))
  print("Maximum Weight", np.max(children[ind]))
  print("Minimum Cost", np.min(fit))
# Out:
# Highest Fitness 721.0
# Generation Number 0
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 60.0
# Highest Fitness 791.0
# Generation Number 1
# Weight of Solution 11
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 38.0
# Highest Fitness 925.0
# Generation Number 2
# Weight of Solution 18
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 140.0
# Highest Fitness 678.0
# Generation Number 3
# Weight of Solution 11
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 55.0
# Highest Fitness 739.0
# Generation Number 4
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 21.0
# Highest Fitness 734.0
# Generation Number 5
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 71.0
# Highest Fitness 946.0
# Generation Number 6
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 58.0
# Highest Fitness 723.0
# Generation Number 7
# Weight of Solution 14
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 117.0
# Highest Fitness 947.0
# Generation Number 8
# Weight of Solution 15
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 129.0
# Highest Fitness 713.0
# Generation Number 9
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 104.0
# Highest Fitness 699.0
# Generation Number 10
# Weight of Solution 11
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 121.0
# Highest Fitness 662.0
# Generation Number 11
# Weight of Solution 9
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 0.0
# Highest Fitness 829.0
# Generation Number 12
# Weight of Solution 11
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 169.0
# Highest Fitness 725.0
# Generation Number 13
# Weight of Solution 10
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 29.0
# Highest Fitness 714.0
# Generation Number 14
# Weight of Solution 10
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 42.0
# Highest Fitness 731.0
# Generation Number 15
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 95.0
# Highest Fitness 951.0
# Generation Number 16
# Weight of Solution 14
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 60.0
# Highest Fitness 705.0
# Generation Number 17
# Weight of Solution 8
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 120.0
# Highest Fitness 762.0
# Generation Number 18
# Weight of Solution 8
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 14.0
# Highest Fitness 596.0
# Generation Number 19
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 91.0
# Highest Fitness 800.0
# Generation Number 20
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 34.0
# Highest Fitness 773.0
# Generation Number 21
# Weight of Solution 11
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 129.0
# Highest Fitness 700.0
# Generation Number 22
# Weight of Solution 16
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 107.0
# Highest Fitness 640.0
# Generation Number 23
# Weight of Solution 9
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 52.0
# Highest Fitness 755.0
# Generation Number 24
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 31.0
# Highest Fitness 757.0
# Generation Number 25
# Weight of Solution 14
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 75.0
# Highest Fitness 808.0
# Generation Number 26
# Weight of Solution 10
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 68.0
# Highest Fitness 802.0
# Generation Number 27
# Weight of Solution 15
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 97.0
# Highest Fitness 882.0
# Generation Number 28
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 61.0
# Highest Fitness 780.0
# Generation Number 29
# Weight of Solution 10
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 0.0
# Highest Fitness 595.0
# Generation Number 30
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 43.0
# Highest Fitness 692.0
# Generation Number 31
# Weight of Solution 7
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 25.0
# Highest Fitness 661.0
# Generation Number 32
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 71.0
# Highest Fitness 875.0
# Generation Number 33
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 90.0
# Highest Fitness 904.0
# Generation Number 34
# Weight of Solution 17
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 85.0
# Highest Fitness 820.0
# Generation Number 35
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 62.0
# Highest Fitness 859.0
# Generation Number 36
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 119.0
# Highest Fitness 917.0
# Generation Number 37
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 106.0
# Highest Fitness 707.0
# Generation Number 38
# Weight of Solution 14
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 79.0
# Highest Fitness 844.0
# Generation Number 39
# Weight of Solution 11
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 116.0
# Highest Fitness 899.0
# Generation Number 40
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 110.0
# Highest Fitness 713.0
# Generation Number 41
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 53.0
# Highest Fitness 778.0
# Generation Number 42
# Weight of Solution 15
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 43.0
# Highest Fitness 767.0
# Generation Number 43
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 73.0
# Highest Fitness 742.0
# Generation Number 44
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 93.0
# Highest Fitness 679.0
# Generation Number 45
# Weight of Solution 9
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 48.0
# Highest Fitness 819.0
# Generation Number 46
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 31.0
# Highest Fitness 722.0
# Generation Number 47
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 39.0
# Highest Fitness 751.0
# Generation Number 48
# Weight of Solution 11
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 65.0
# Highest Fitness 607.0
# Generation Number 49
# Weight of Solution 6
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 82.0
# Highest Fitness 717.0
# Generation Number 50
# Weight of Solution 9
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 98.0
# Highest Fitness 665.0
# Generation Number 51
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 36.0
# Highest Fitness 680.0
# Generation Number 52
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 118.0
# Highest Fitness 737.0
# Generation Number 53
# Weight of Solution 10
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 79.0
# Highest Fitness 765.0
# Generation Number 54
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 28.0
# Highest Fitness 675.0
# Generation Number 55
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 99.0
# Highest Fitness 829.0
# Generation Number 56
# Weight of Solution 17
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 23.0
# Highest Fitness 762.0
# Generation Number 57
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 16.0
# Highest Fitness 656.0
# Generation Number 58
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 59.0
# Highest Fitness 894.0
# Generation Number 59
# Weight of Solution 14
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 38.0
# Highest Fitness 805.0
# Generation Number 60
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 92.0
# Highest Fitness 806.0
# Generation Number 61
# Weight of Solution 11
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 71.0
# Highest Fitness 667.0
# Generation Number 62
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 73.0
# Highest Fitness 851.0
# Generation Number 63
# Weight of Solution 14
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 104.0
# Highest Fitness 734.0
# Generation Number 64
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 23.0
# Highest Fitness 778.0
# Generation Number 65
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 73.0
# Highest Fitness 792.0
# Generation Number 66
# Weight of Solution 11
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 10.0
# Highest Fitness 631.0
# Generation Number 67
# Weight of Solution 10
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 68.0
# Highest Fitness 900.0
# Generation Number 68
# Weight of Solution 16
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 80.0
# Highest Fitness 842.0
# Generation Number 69
# Weight of Solution 11
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 31.0
# Highest Fitness 863.0
# Generation Number 70
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 26.0
# Highest Fitness 761.0
# Generation Number 71
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 61.0
# Highest Fitness 734.0
# Generation Number 72
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 68.0
# Highest Fitness 938.0
# Generation Number 73
# Weight of Solution 11
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 123.0
# Highest Fitness 795.0
# Generation Number 74
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 58.0
# Highest Fitness 681.0
# Generation Number 75
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 40.0
# Highest Fitness 672.0
# Generation Number 76
# Weight of Solution 9
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 95.0
# Highest Fitness 762.0
# Generation Number 77
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 28.0
# Highest Fitness 780.0
# Generation Number 78
# Weight of Solution 14
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 62.0
# Highest Fitness 841.0
# Generation Number 79
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 68.0
# Highest Fitness 804.0
# Generation Number 80
# Weight of Solution 10
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 59.0
# Highest Fitness 833.0
# Generation Number 81
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 82.0
# Highest Fitness 666.0
# Generation Number 82
# Weight of Solution 14
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 76.0
# Highest Fitness 785.0
# Generation Number 83
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 119.0
# Highest Fitness 662.0
# Generation Number 84
# Weight of Solution 9
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 112.0
# Highest Fitness 712.0
# Generation Number 85
# Weight of Solution 11
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 30.0
# Highest Fitness 863.0
# Generation Number 86
# Weight of Solution 10
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 124.0
# Highest Fitness 900.0
# Generation Number 87
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 96.0
# Highest Fitness 599.0
# Generation Number 88
# Weight of Solution 9
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 63.0
# Highest Fitness 872.0
# Generation Number 89
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 138.0
# Highest Fitness 845.0
# Generation Number 90
# Weight of Solution 11
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 108.0
# Highest Fitness 821.0
# Generation Number 91
# Weight of Solution 14
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 66.0
# Highest Fitness 662.0
# Generation Number 92
# Weight of Solution 14
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 73.0
# Highest Fitness 753.0
# Generation Number 93
# Weight of Solution 10
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 0.0
# Highest Fitness 702.0
# Generation Number 94
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 0.0
# Highest Fitness 865.0
# Generation Number 95
# Weight of Solution 14
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 108.0
# Highest Fitness 774.0
# Generation Number 96
# Weight of Solution 13
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 56.0
# Highest Fitness 749.0
# Generation Number 97
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 51.0
# Highest Fitness 738.0
# Generation Number 98
# Weight of Solution 12
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 74.0
# Highest Fitness 774.0
# Generation Number 99
# Weight of Solution 11
# Minimum Weight 0
# Maximum Weight 1
# Minimum Cost 89.0

# %% [markdown]
# #### Print following data
#
# ```generation, best cost, min_cost, best weight, min_weight, max weight``` for all generations.
#
# #### Plot following graphs
#
# 1.  **cost, min_cost** with respect to generation number
# 2.   **max weight, best weight, min_weight** with respect to generation number

# %%
import matplotlib.pyplot as plt
print("generation  best cost  min_cost  best weight  min_weight  max weight")
gen=[]
for i in range(ga_generations):
  gen.append(i)
  print("{:-3d}         {:-4.1f}      {:-3.1f}        {:-3.1f}           {:-3.1f}           {:-3.1f}".format(i,best_cost[i],min_cost[i],best_weight[i],min_weight[i],max_weight[i]))
ax,fig=plt.subplots(1, 1)
plt.plot(gen, best_cost)
plt.plot(gen, min_cost)

ax2,fig2=plt.subplots(1, 1)
plt.plot(gen, max_weight)
plt.plot(gen, best_weight)
plt.plot(gen, min_weight)
# Out:
# generation  best cost  min_cost  best weight  min_weight  max weight
#   0         1721.0      0.0        0.3           0.0           5.3
#   1         1812.9      0.0        0.3           0.0           7.4
#   2         946.9      0.0        0.2           0.0           7.5
#   3         1715.7      0.0        0.3           0.0           7.5
#   4         1697.7      0.0        0.3           0.0           6.8
#   5         1567.0      0.0        0.3           0.0           7.4
#   6         2229.0      0.0        0.3           0.0           7.4
#   7         1600.5      0.0        0.5           0.0           6.5
#   8         1799.1      0.0        0.3           0.0           5.0
#   9         1338.7      0.0        0.3           0.0           5.2
#  10         1995.7      0.0        0.3           0.0           6.3
#  11         1580.8      0.0        0.3           0.0           4.6
#  12         1218.0      0.0        0.3           0.0           4.6
#  13         1946.3      0.0        0.3           0.0           5.6
#  14         1498.4      0.0        0.3           0.0           7.0
#  15         1660.5      0.0        0.3           0.0           6.0
#  16         1794.6      0.0        0.3           0.0           5.3
#  17         1243.8      0.0        0.3           0.0           7.0
#  18         1431.4      0.0        0.3           0.0           7.0
#  19         1770.1      0.0        0.3           0.0           9.7
#  20         2227.6      0.0        0.4           0.0           8.4
#  21         1603.9      0.0        0.3           0.0           5.3
#  22         1602.6      0.0        0.3           0.0           5.3
#  23         1207.3      0.0        0.3           0.0           4.4
#  24         1297.9      0.0        0.3           0.0           7.0
#  25         1311.2      0.0        0.4           0.0           9.2
#  26         2070.8      0.0        0.3           0.0           7.4
#  27         1316.0      0.0        0.4           0.0           6.0
#  28         1337.9      0.0        0.3           0.0           6.9
#  29         1473.4      0.0        0.3           0.0           6.3
#  30         1995.5      0.0        0.4           0.0           5.3
#  31         1406.6      0.0        0.3           0.0           5.4
#  32         2157.5      0.0        0.3           0.0           6.3
#  33         1599.1      0.0        0.3           0.0           7.0
#  34         1781.3      0.0        0.4           0.0           7.0
#  35         1851.2      0.0        0.2           0.0           7.3
#  36         1573.7      0.0        0.3           0.0           7.8
#  37         1609.9      0.0        0.5           0.0           7.5
#  38         2255.7      0.0        0.3           0.0           7.3
#  39         1817.5      0.0        0.2           0.0           7.4
#  40         2136.3      0.0        0.2           0.0           7.4
#  41         1155.1      0.0        0.3           0.0           6.4
#  42         1907.2      0.0        0.2           0.0           7.4
#  43         2061.1      0.0        0.3           0.0           7.3
#  44         1530.3      0.0        0.3           0.0           5.3
#  45         1304.3      0.0        0.3           0.0           7.0
#  46         1768.5      0.0        0.3           0.0           5.6
#  47         2126.6      0.0        0.4           0.0           5.3
#  48         2643.6      0.0        0.3           0.0           7.3
#  49         1442.2      0.0        0.3           0.0           4.6
#  50         2003.2      0.0        0.4           0.0           5.2
#  51         1714.9      0.0        0.4           0.0           7.0
#  52         1594.4      0.0        0.2           0.0           7.4
#  53         1421.7      0.0        0.2           0.0           7.4
#  54         1668.6      0.0        0.3           0.0           7.4
#  55         1293.6      0.0        0.3           0.0           6.3
#  56         1956.0      0.0        0.3           0.0           5.3
#  57         1870.2      0.0        0.3           0.0           5.3
#  58         1659.8      0.0        0.3           0.0           5.8
#  59         1999.4      0.0        0.2           0.0           6.3
#  60         2425.6      0.0        0.3           0.0           7.4
#  61         1945.7      0.0        0.3           0.0           5.0
#  62         1577.0      0.0        0.2           0.0           7.4
#  63         1075.4      0.0        0.2           0.0           5.0
#  64         1697.4      0.0        0.3           0.0           5.3
#  65         1645.8      0.0        0.2           0.0           7.3
#  66         2699.8      0.0        0.3           0.0           7.3
#  67         1567.3      0.0        0.3           0.0           7.5
#  68         1717.1      0.0        0.3           0.0           6.4
#  69         2048.0      0.0        0.3           0.0           7.5
#  70         1475.7      0.0        0.4           0.0           6.3
#  71         1894.2      0.0        0.3           0.0           7.4
#  72         1384.5      0.0        0.2           0.0           7.4
#  73         1660.9      0.0        0.3           0.0           5.2
#  74         2012.8      0.0        0.3           0.0           5.3
#  75         1940.4      0.0        0.2           0.0           7.3
#  76         1971.6      0.0        0.4           0.0           6.4
#  77         1936.7      0.0        0.4           0.0           6.4
#  78         1889.1      0.0        0.3           0.0           7.5
#  79         1610.7      0.0        0.3           0.0           5.6
#  80         1412.9      0.0        0.4           0.0           5.3
#  81         1646.6      0.0        0.3           0.0           7.5
#  82         2164.3      0.0        0.3           0.0           7.5
#  83         1599.5      0.0        0.3           0.0           5.6
#  84         1346.3      0.0        0.2           0.0           7.3
#  85         1733.1      0.0        0.4           0.0           7.3
#  86         1922.3      0.0        0.2           0.0           7.4
#  87         1644.3      0.0        0.2           0.0           7.3
#  88         1612.7      0.0        0.4           0.0           6.8
#  89         1392.1      0.0        0.2           0.0           7.3
#  90         1548.9      0.0        0.3           0.0           9.7
#  91         1879.4      0.0        0.3           0.0           5.6
#  92         1284.2      0.0        0.3           0.0           5.2
#  93         1227.2      0.0        0.3           0.0           6.8
#  94         1543.9      0.0        0.3           0.0           6.8
#  95         1641.0      0.0        0.3           0.0           4.6
#  96         2036.4      0.0        0.3           0.0           5.3
#  97         2088.7      0.0        0.3           0.0           5.6
#  98         2156.1      0.0        0.3           0.0           6.3
#  99         2342.8      0.0        0.4           0.0           6.3

# %% [markdown]
# # Task 2 Particle Swarm optimization
#
# Implement Particle swarm optimization algorithm and find the global minimum of the Rosenbrock's banana function.

# %%
# Example
def banana(xx):
  x = xx[0]
  y = xx[1]
  return x**4 - 2*y*x**2 + y**2 + x**2 - 2*x + 5

# limits for searching solution
lower_bound = [-5, -5]
upper_bound = [5, 5]

# %% [markdown]
# Define python function
# ```python
# def lab6-pso(objective, l_bound, u_bound,
#        swarmsize, dimension,
#        iterations=100, omega=0.5, phip=0.5, phig=0.5):
#        return [best_global, obj_global]
# ```
# Function arguments:
#
# *   **objective** is the objective function, i.e. the banana function for us (see above)
# *   **l_bound** - lower bound of the area for searching a solution
# *   **u_bound** - upper bound of the area for searching a solution
# *   **swarmsize** - number of particles in the swarm
# *   **dimension** - the dimension of the searching space. Banana function is a function of two variables so that each particle is a two dimensional vector [x, y].
# *   **interations** - a stop criterion of the algorithm, which will stop the algorithm after certain number of iterations
# *   **omega** - $\omega$ parameter of the algorithm
# *   **phip** - $\phi_p$ parameter of the algorithm
# *   **phig** - $\phi_g$ parameter of the algorithm
#
# ### PSO Algorithm
#
# 1. **Initialize the swarm.** The swarm is an numpy array of shape ( $N_S, N_D$ ) of np.float64 data type. $N_S$ is swarmsize and $N_D = 2$ is the dimension of the position of the particle. Position of each particle is initialized randomly from uniform distribution within the area given by lower and upper bounds, i.e. a position of the particle (solution) is a vector $[x, y]$ where $x \in <-5.0,5.0>$ and $y \in <-5.0, 5.0>$.
#
# 2. **Set best_local variable for each particle.**
# In this place it is a simple deep copy  of the swarm numpy matrix (swarm.copy()).
#
# 3. **Evaluate the objective function for all particles in the swarm.** Simply said, call the objective function for each row in the swarm matrix and store them in the obj_local array (local best objective values).
#
# 4. **Find the index $i$ of minimum of the objective value in the array**, i.e. get the best solution of the swarm. Perform deep copy of the row at index $i$ to variable best_global and assign the objective value at index $i$ to variable obj_global. Both variables represent best global solution for the swarm. **Hint:** use the numpy.argmin function
#
# 5. **Initialize the velocity matrix $v_t$** for $t=-1$. This is a  numpy matrix of the shape of $(N_S, N_D)$ where $N_S$ and the type of numpy.float64
# 6. **Prepare the loop for all iterations.**. The loop body starts.
#
# >> 6-1. **Generate random number matrixes** ${\bf r}_p \in <0,1>^{N_SN_D}$ and ${\bf r}_p \in <0,1>^{N_SN_D}$.
#
# >> 6-2. **Calculate velocities and positions of particles.** The particle velocity is given by equation
# $${\bf v}_t=\omega {\bf v}_{t-1} + \phi_p{\bf r}_p(p_{\text{best}} - {\bf x}_t) + \phi_g{\bf r}_g(g_{\text{best}} - {\bf x}_t)
# $$
# where $p_{\text{best}}$ is the particle best solution (position), $g_{\text{best}}$ is the global best solution (position) and ${\bf x}_t$. The position of the particle is updated by
# $$
#   {\bf x}_{t+1}={\bf x}_t + {\bf v}_t
# $$
#
# >> 6-3. **Calculate objective function** for all particles and store them in the numpy array. Compare current objective values to values in the obj_local array. If new objective value is less than previously stored objective local value, update the obj_local array and also store new best_local position for the particle.
#
# >> 6-4. **Find the index $i$ of minimum of the objective value in the array**, i.e. get the best solution of the swarm. If the minimum value is less than previously stored (in obj_global) perform deep copy of the row at index $i$ to variable best_global and assign the objective value at index $i$ to variable obj_global. Both variables represent best global solution for the swarm. **Hint:** use the numpy.argmin function.
#
# >> 6-5. **Continue at point 6-1**, until the total number of iterations is reached.
#
# 7. **Return the best solution** (position and objective)

# %%
swarmsize = 100
def update_velocity(swarm, velocity, pbest, gbest, phip, phig, omega):
  num_particle = len(swarm)
  new_velocity = np.array([0.0 for i in range(num_particle)])
  r1 = random.uniform(0,1)
  r2 = random.uniform(0,1)
  for i in range(num_particle):
    new_velocity[i] = omega*velocity[i] + phip*r1*(pbest[i]-swarm[i])+phig*r2*(gbest[i]-swarm[i])
  return new_velocity

def update_position(swarm, velocity):
  new_particle = swarm + velocity
  return new_particle

def pso(objective, l_bound, u_bound, 
             swarmsize, dimensions=2,
             iterations=100, omega=0.5,phip=0.5,phig=0.5):
  obj_loc_array = []
  swarm = [[random.uniform(l_bound[0], u_bound[0]) for j in range(dimensions)] for i in range(swarmsize)]
  count = 0
  best_loc = swarm.copy()
  obj_loc_array = [objective(i) for i in swarm]
  best_global_ind = np.argmin(obj_loc_array)
  best_global = obj_loc_array[best_global_ind]
  obj_global = best_loc[best_global_ind]
  velocity = [[0.0 for j in range(dimensions)] for i in range(swarmsize)]
  for g in range(iterations):
    for i in range(swarmsize):
      velocity[i] = update_velocity(swarm[i], velocity[i], best_loc[i], obj_global, phip, phig, omega)
      swarm[i] = (update_position(swarm[i], velocity[i]))
    obj_loc_array_new = [objective(i) for i in swarm]
    #print(obj_loc_array_new)
    for j in range(len(obj_loc_array_new)):
      if obj_loc_array_new[j] < obj_loc_array_new[j]:
        obj_loc_array[j] = obj_loc_array_new[j]
        count+=1
    if np.min(obj_loc_array_new)<best_global:
      best_global_ind = np.argmin(obj_loc_array_new)
      best_global = obj_loc_array_new[best_global_ind]
      obj_global = best_loc[best_global_ind]
      print(best_global)
  return [best_global, obj_global]

# %% [markdown]
# Run the PSO algorithm and print the best solution.

# %%
pso(banana, lower_bound, upper_bound, swarmsize)
# Out:
# 4.232015163613923
# 4.116049008637702
# 4.016446703883572
# 4.004478914309482
# 4.004074453480436
# 4.001304169175251
# [4.001304169175251, [-4.92590325753135, 1.7200188799452967]]

# %% [markdown]
# ## Subtask 1
#
# Use pyswarm package for the same task.
#
# **Hint:** Do not use constraints.

# %%
# Example
# !pip install pyswarm
import pyswarm
from pyswarm import pso
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyswarm in /usr/local/lib/python3.8/dist-packages (0.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from pyswarm) (1.21.6)

# %%
solution, objective = pso(banana, lower_bound, upper_bound)
print("Solution: ", solution)
print("Objective: ", objective)
# Out:
# Stopping search: Swarm best objective change less than 1e-08
# Solution:  [0.99998911 0.99999851]
# Objective:  4.000000000530138
